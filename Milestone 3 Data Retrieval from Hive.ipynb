# %%
#Guide to install SASL in Windows
#https://stackoverflow.com/questions/26505882/unable-to-install-sasl-0-1-3-python-package-on-windows-machine
#install using Anaconda prompt already
#pip install sasl
#pip install thrift
#pip install thrift-sasl
#pip install PyHive

# %%
from pyhive import hive

# %%
from IPython.display import Image
Image("C:\\Users\\loel7003\\Documents\\WQD180022\\Hive.png")

# %% [markdown]
# A database named HOUSE is created in Hive. Within the database, I have store 2 tables named klhouse and selhouse. The information is required for data extraction in the next step.

# %%
from IPython.display import Image
Image("C:\\Users\\loel7003\\Documents\\WQD180022\\Hive_Site.png")

# %% [markdown]
# In the hive site xml file, we have identify the authentication method to be NONE, localhost is used and we are using hiveserver2 which by default is in port 10000.

# %%
conn = hive.Connection(host='localhost',port=10000,auth='NONE',database='HOUSE')
# Out:
# Could not connect to any of [('127.0.0.1', 10000), ('::1', 10000, 0, 0)]
# ---------------------------------------------------------------------------
# TTransportException                       Traceback (most recent call last)
# <ipython-input-36-60870dea527b> in <module>
# ----> 1 conn = hive.Connection(host='localhost',port=10000,auth='NOSASL',database='HOUSE')
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pyhive\hive.py in __init__(self, host, port, username, database, auth, configuration, kerberos_service_name, password, thrift_transport)
#     190
#     191         try:
# --> 192             self._transport.open()
#     193             open_session_req = ttypes.TOpenSessionReq(
#     194                 client_protocol=protocol_version,
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\thrift\transport\TTransport.py in open(self)
#     153
#     154     def open(self):
# --> 155         return self.__trans.open()
#     156
#     157     def close(self):
#
# ...

# %%
cursor = conn.cursor()
cursor.execute("SELECT * FROM klhouse")
for result in cursor.fetchall():
  use_result(result)

# %%
import pandas as pd
klhouse = pd.read_sql("SELECT * FROM klhouse", conn)

# %%
cursor = conn.cursor()
cursor.execute("SELECT * FROM selhouse")
for result in cursor.fetchall():
  use_result(result)

# %%
selhouse = pd.read_sql("SELECT * FROM selhouse", conn)
